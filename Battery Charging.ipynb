# %%
#First step :- Load libraries
from keras.models import Sequential
from keras.layers import Dense      #neural net layers
import pandas as pd
from sklearn.model_selection import train_test_split   #to spit dataset into train,validation,test
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

import tensorflow as tf

# !pip install -q xlrd           #library to read from excel sheet
import io                      #input-output = io
from google.colab import files #important to locally save files
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth    #to use Google Cloud SDK
from pydrive.drive import GoogleDrive
from google.colab import auth           #to authenticate gmail ID
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()   #to authenticate gmail ID in Google Cloud SDK
drive = GoogleDrive(gauth)

import math

from IPython import display
from matplotlib import cm
from matplotlib import gridspec
import numpy as np
from sklearn import metrics

# to find MSE of overall data
def mse(actual, pred):
    actual, pred = np.array(actual), np.array(pred)
    return np.square(np.subtract(actual,pred)).mean()


def rmse(actual, pred):
    actual, pred = np.array(actual), np.array(pred)
    return np.sqrt(np.square(np.subtract(actual,pred)).mean())

# %%
#Store the data set
file_id = '12ofZQQnCKcXxOrBMiFDPvZJ9f1hvVoHf' #file key of google sheet

downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('ChargingTest.xlsx')

df = pd.read_excel('ChargingTest.xlsx')

dataset = df.values                        #Convert the data into an array
inputs  = dataset[1:100,0:9]               #set input data
targets = dataset[1:100,9:10]               #set output data

# %%
#How to split this into train & test data?
X_train, x_test, Y_train, y_test = train_test_split(inputs, targets, test_size=0.2, random_state = 4)
#Split train into train & validation(80% train, 20% test, 20% val)
x_train, x_val, y_train, y_val = train_test_split(X_train, Y_train, test_size=0.25, random_state=1)
#Why 0.25? Because 0.25 x 0.8 = 0.2

#from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)   #Standardizing all the values
X_test = sc.fit_transform(x_test)
Y_train = sc.fit_transform(y_train)
Y_test = sc.fit_transform(y_test)
INPUTS = sc.fit_transform(inputs)
TARGETS = sc.fit_transform(targets)
X_val = sc.fit_transform(x_val)
Y_val = sc.fit_transform(y_val)

# %%
tf.keras.backend.clear_session() #close the previous model variable before starting a fresh run

# %%
#Voila, now lets build Neural network model
from keras.layers import LeakyReLU
model = Sequential([                                                      #Sequential specifies to keras that we are creating model sequentially and the output of each layer we add is input to the next layer we specify.
                    Dense(4, activation = 'sigmoid', input_shape=(9, )), #you only need to specify no. of attibutes aka input_shape for first HIDDEN layer
                    Dense(9, activation = 'LeakyReLU'),                       #second HIDDEN layer
                    #Dense(8, activation = 'tanh')
])
model.add(Dense(1,))                                 #another way to add a layer. This is the output layer.

# %%
#To specify the loss function and the optimizer
from keras import optimizers
#from keras.optimizers import adam_v2, adagrad_v2, adamax_v2
from keras.optimizers import Adam
import random
#opt = tf.keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss='mse', optimizer = Adam(learning_rate=0.01), metrics=['mae'])

#Training the model
hist = model.fit(X_train, Y_train, validation_split = 0,validation_data = (X_val,Y_val), epochs= 100, batch_size=2)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 1s 10ms/step - loss: 0.7571 - mae: 0.6290 - val_loss: 0.2275 - val_mae: 0.4093
# Epoch 2/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.2691 - mae: 0.2753 - val_loss: 0.0529 - val_mae: 0.1744
# Epoch 3/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2143 - mae: 0.2896 - val_loss: 0.0345 - val_mae: 0.1484
# Epoch 4/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1855 - mae: 0.1944 - val_loss: 0.0238 - val_mae: 0.1292
# Epoch 5/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1565 - mae: 0.2113 - val_loss: 0.0259 - val_mae: 0.1264
# Epoch 6/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1259 - mae: 0.1600 - val_loss: 0.0208 - val_mae: 0.1056
# Epoch 7/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1110 - mae: 0.1704 - val_loss: 0.0165 - val_mae: 0.1133
# Epoch 8/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0770 - mae: 0.1436 - val_loss: 0.0242 - val_mae: 0.1148
# Epoch 9/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0499 - mae: 0.1028 - val_loss: 0.0504 - val_mae: 0.1690
# Epoch 10/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0408 - mae: 0.1128 - val_loss: 0.0245 - val_mae: 0.1148
# Epoch 11/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0227 - mae: 0.0809 - val_loss: 0.0458 - val_mae: 0.1643
# Epoch 12/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0267 - mae: 0.1144 - val_loss: 0.0214 - val_mae: 0.1037
# Epoch 13/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0218 - mae: 0.1039 - val_loss: 0.0460 - val_mae: 0.1483
# Epoch 14/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0140 - mae: 0.0793 - val_loss: 0.0278 - val_mae: 0.1088
# Epoch 15/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0153 - mae: 0.0923 - val_loss: 0.0239 - val_mae: 0.1157
# Epoch 16/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0257 - mae: 0.1241 - val_loss: 0.0705 - val_mae: 0.1686
# Epoch 17/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0099 - mae: 0.0797 - val_loss: 0.0312 - val_mae: 0.1275
# Epoch 18/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0107 - mae: 0.0865 - val_loss: 0.0263 - val_mae: 0.1035
# Epoch 19/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0108 - mae: 0.0775 - val_loss: 0.0338 - val_mae: 0.1408
# Epoch 20/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0231 - mae: 0.1287 - val_loss: 0.0543 - val_mae: 0.1766
# Epoch 21/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0175 - mae: 0.1087 - val_loss: 0.0369 - val_mae: 0.1500
# Epoch 22/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0141 - mae: 0.0926 - val_loss: 0.0246 - val_mae: 0.1154
# Epoch 23/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0102 - mae: 0.0796 - val_loss: 0.0229 - val_mae: 0.1071
# Epoch 24/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0082 - mae: 0.0703 - val_loss: 0.0266 - val_mae: 0.1121
# Epoch 25/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0092 - mae: 0.0782 - val_loss: 0.0461 - val_mae: 0.1758
# Epoch 26/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0092 - mae: 0.0727 - val_loss: 0.0360 - val_mae: 0.1206
# Epoch 27/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0105 - mae: 0.0774 - val_loss: 0.0161 - val_mae: 0.0966
# Epoch 28/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0115 - mae: 0.0857 - val_loss: 0.0398 - val_mae: 0.1317
# Epoch 29/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0140 - mae: 0.0886 - val_loss: 0.0308 - val_mae: 0.1256
# Epoch 30/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0099 - mae: 0.0761 - val_loss: 0.0219 - val_mae: 0.0987
# Epoch 31/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0053 - mae: 0.0569 - val_loss: 0.0329 - val_mae: 0.1144
# Epoch 32/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0092 - mae: 0.0763 - val_loss: 0.0265 - val_mae: 0.1195
# Epoch 33/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137 - mae: 0.0971 - val_loss: 0.0493 - val_mae: 0.1670
# Epoch 34/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0174 - mae: 0.0986 - val_loss: 0.0522 - val_mae: 0.1762
# Epoch 35/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0067 - mae: 0.0675 - val_loss: 0.0347 - val_mae: 0.1431
# Epoch 36/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0063 - mae: 0.0655 - val_loss: 0.0338 - val_mae: 0.1342
# Epoch 37/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0070 - mae: 0.0646 - val_loss: 0.0256 - val_mae: 0.1094
# Epoch 38/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0052 - mae: 0.0536 - val_loss: 0.0243 - val_mae: 0.0904
# Epoch 39/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0061 - mae: 0.0631 - val_loss: 0.0361 - val_mae: 0.1366
# Epoch 40/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0177 - mae: 0.1007 - val_loss: 0.0154 - val_mae: 0.0884
# Epoch 41/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0046 - mae: 0.0582 - val_loss: 0.0328 - val_mae: 0.1191
# Epoch 42/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0059 - mae: 0.0602 - val_loss: 0.0335 - val_mae: 0.1197
# Epoch 43/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0045 - mae: 0.0502 - val_loss: 0.0295 - val_mae: 0.1061
# Epoch 44/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0041 - mae: 0.0491 - val_loss: 0.0265 - val_mae: 0.1029
# Epoch 45/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0041 - mae: 0.0472 - val_loss: 0.0212 - val_mae: 0.0869
# Epoch 46/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0039 - mae: 0.0491 - val_loss: 0.0331 - val_mae: 0.1303
# Epoch 47/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0099 - mae: 0.0739 - val_loss: 0.0438 - val_mae: 0.1328
# Epoch 48/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0048 - mae: 0.0530 - val_loss: 0.0277 - val_mae: 0.1074
# Epoch 49/100
# 30/30 [==============================] - 0s 12ms/step - loss: 0.0047 - mae: 0.0508 - val_loss: 0.0354 - val_mae: 0.1056
# Epoch 50/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0049 - mae: 0.0490 - val_loss: 0.0262 - val_mae: 0.0887
# Epoch 51/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0072 - mae: 0.0658 - val_loss: 0.0318 - val_mae: 0.1274
# Epoch 52/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0129 - mae: 0.0949 - val_loss: 0.0294 - val_mae: 0.1115
# Epoch 53/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0039 - mae: 0.0461 - val_loss: 0.0367 - val_mae: 0.1250
# Epoch 54/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0040 - mae: 0.0511 - val_loss: 0.0161 - val_mae: 0.0663
# Epoch 55/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0026 - mae: 0.0414 - val_loss: 0.0346 - val_mae: 0.0970
# Epoch 56/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0037 - mae: 0.0470 - val_loss: 0.0254 - val_mae: 0.1187
# Epoch 57/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0094 - mae: 0.0751 - val_loss: 0.0189 - val_mae: 0.1137
# Epoch 58/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0091 - mae: 0.0792 - val_loss: 0.0543 - val_mae: 0.1599
# Epoch 59/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0065 - mae: 0.0656 - val_loss: 0.0152 - val_mae: 0.0786
# Epoch 60/100
# 30/30 [==============================] - 1s 23ms/step - loss: 0.0053 - mae: 0.0520 - val_loss: 0.0306 - val_mae: 0.1187
# Epoch 61/100
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0057 - mae: 0.0539 - val_loss: 0.0401 - val_mae: 0.1313
# Epoch 62/100
# 30/30 [==============================] - 0s 15ms/step - loss: 0.0026 - mae: 0.0379 - val_loss: 0.0301 - val_mae: 0.1068
# Epoch 63/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0084 - mae: 0.0709 - val_loss: 0.0413 - val_mae: 0.1164
# Epoch 64/100
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0036 - mae: 0.0447 - val_loss: 0.0356 - val_mae: 0.1054
# Epoch 65/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0044 - mae: 0.0533 - val_loss: 0.0396 - val_mae: 0.1095
# Epoch 66/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0038 - mae: 0.0448 - val_loss: 0.0352 - val_mae: 0.1324
# Epoch 67/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0102 - mae: 0.0816 - val_loss: 0.0357 - val_mae: 0.1482
# Epoch 68/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0098 - mae: 0.0830 - val_loss: 0.0693 - val_mae: 0.1635
# Epoch 69/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0055 - mae: 0.0594 - val_loss: 0.0136 - val_mae: 0.0828
# Epoch 70/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0063 - mae: 0.0613 - val_loss: 0.0378 - val_mae: 0.1234
# Epoch 71/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0049 - mae: 0.0551 - val_loss: 0.0262 - val_mae: 0.0961
# Epoch 72/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0021 - mae: 0.0361 - val_loss: 0.0301 - val_mae: 0.1448
# Epoch 73/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0040 - mae: 0.0460 - val_loss: 0.0286 - val_mae: 0.1108
# Epoch 74/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0023 - mae: 0.0374 - val_loss: 0.0413 - val_mae: 0.1127
# Epoch 75/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0022 - mae: 0.0355 - val_loss: 0.0252 - val_mae: 0.0998
# Epoch 76/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0030 - mae: 0.0447 - val_loss: 0.0235 - val_mae: 0.0857
# Epoch 77/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0023 - mae: 0.0373 - val_loss: 0.0396 - val_mae: 0.1191
# Epoch 78/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0025 - mae: 0.0372 - val_loss: 0.0317 - val_mae: 0.1187
# Epoch 79/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - mae: 0.0431 - val_loss: 0.0227 - val_mae: 0.0973
# Epoch 80/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0037 - mae: 0.0471 - val_loss: 0.0341 - val_mae: 0.1143
# Epoch 81/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0048 - mae: 0.0523 - val_loss: 0.0186 - val_mae: 0.0903
# Epoch 82/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0028 - mae: 0.0440 - val_loss: 0.0320 - val_mae: 0.1015
# Epoch 83/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0024 - mae: 0.0359 - val_loss: 0.0164 - val_mae: 0.0965
# Epoch 84/100
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0041 - mae: 0.0449 - val_loss: 0.0353 - val_mae: 0.1137
# Epoch 85/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0057 - mae: 0.0610 - val_loss: 0.0268 - val_mae: 0.0856
# Epoch 86/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0043 - mae: 0.0554 - val_loss: 0.0414 - val_mae: 0.1516
# Epoch 87/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0043 - mae: 0.0512 - val_loss: 0.0332 - val_mae: 0.1190
# Epoch 88/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0037 - mae: 0.0444 - val_loss: 0.0288 - val_mae: 0.1052
# Epoch 89/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0025 - mae: 0.0378 - val_loss: 0.0420 - val_mae: 0.1190
# Epoch 90/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0031 - mae: 0.0449 - val_loss: 0.0137 - val_mae: 0.0876
# Epoch 91/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0048 - mae: 0.0538 - val_loss: 0.0408 - val_mae: 0.1020
# Epoch 92/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0041 - mae: 0.0481 - val_loss: 0.0248 - val_mae: 0.1246
# Epoch 93/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0102 - mae: 0.0785 - val_loss: 0.0287 - val_mae: 0.1248
# Epoch 94/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0078 - mae: 0.0725 - val_loss: 0.0339 - val_mae: 0.1212
# Epoch 95/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0046 - mae: 0.0536 - val_loss: 0.0507 - val_mae: 0.1696
# Epoch 96/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0058 - mae: 0.0589 - val_loss: 0.0315 - val_mae: 0.1391
# Epoch 97/100
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0189 - mae: 0.1088 - val_loss: 0.0494 - val_mae: 0.1404
# Epoch 98/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0243 - mae: 0.1292 - val_loss: 0.0318 - val_mae: 0.1333
# Epoch 99/100
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0126 - mae: 0.0831 - val_loss: 0.0982 - val_mae: 0.1559
# Epoch 100/100
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0161 - mae: 0.0934 - val_loss: 0.0239 - val_mae: 0.1052

# %%
#To extract weights from the Neural network
#print(model.get_weights())

# %%
#Visualize the training loss and the validation loss to see if the model is overfitting
plt.plot(hist.history['loss'], 'k-')
plt.plot(hist.history['val_loss'], 'b--')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val', 'test'], loc='upper right')
plt.show()

#Visualize the training accuracy and the validation accuracy to see if the model is overfitting
plt.plot(hist.history['mae'], 'k-')
plt.plot(hist.history['val_mae'], 'b--')
plt.title('', fontsize = 16)
plt.ylabel(' mae')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
# inverse transform
y_pred = model.predict(INPUTS)
y_pred_inv = sc.inverse_transform(y_pred)

y_predtrain = model.predict(X_train)
y_predtrain_inv = sc.inverse_transform(y_predtrain)

y_predval = model.predict(X_val)
y_predval_inv = sc.inverse_transform(y_predval)

y_predtest = model.predict(X_test)
y_predtest_inv = sc.inverse_transform(y_predtest)
# Out:
# 4/4 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 88ms/step

# %%
print(y_predval_inv)
# Out:
# [[0.97874606]
#  [0.95431864]
#  [0.9856043 ]
#  [0.95204705]
#  [0.9833952 ]
#  [0.95339364]
#  [0.960926  ]
#  [0.95672065]
#  [0.98953664]
#  [0.96178114]
#  [0.982869  ]
#  [0.97078717]
#  [0.9737344 ]
#  [0.9439765 ]
#  [0.98485166]
#  [0.95668936]
#  [0.95756394]
#  [0.9564669 ]
#  [0.98277926]
#  [0.98372716]]

# %%
# calculating R2 values of standardized variables. The results are slightly better
from sklearn.metrics import r2_score
r2_all1 = r2_score(TARGETS, y_pred)
r2_test1 = r2_score(Y_test, y_predtest)
r2_train1 = r2_score(Y_train, y_predtrain)
r2_val1 = r2_score(Y_val, y_predval)
print ('r2 Train',r2_train1)
print ('r2 Test',r2_test1)
print ('r2 validation',r2_val1)
print ('r2 overall',r2_all1)
# Out:
# r2 Train 0.9926551597552427
# r2 Test 0.9414805130959416
# r2 validation 0.9760930089250328
# r2 overall 0.989405417943226

# %%
# plotting overall fit
z=[]
a=[]
e=[]

for i in range(0,len(y_pred)):
  z.append(inputs[i][1])
  a.append(targets[i][0])
  e.append(y_pred_inv[i][0])
r=np.array(z)
n=np.array(a)
t = np.array(e)

plt.scatter(a,e)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')

plt.plot(np.unique(a), np.poly1d(np.polyfit(a, e, 1))(np.unique(a)))

#plt.text(0.6,0.5,'R-squared = %0.2f' % r2_all)

# %%
# plotting training fit
z=[]
a=[]
e=[]

for i in range(0,len(Y_train)):
  z.append(x_train[i][1])
  a.append(y_train[i][0])
  e.append(y_predtrain_inv[i][0])
r=np.array(z)
n=np.array(a)
t = np.array(e)

plt.scatter(a,e)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')

plt.plot(np.unique(a), np.poly1d(np.polyfit(a, e, 1))(np.unique(a)))

#plt.text(0.6, 0.5, 'R-squared = %0.2f' % r2_train)

# %%
# plotting testing fit
z=[]
a=[]
e=[]

for i in range(0,len(Y_test)):
  z.append(x_test[i][1])
  a.append(y_test[i][0])
  e.append(y_predtest_inv[i][0])
r=np.array(z)
n=np.array(a)
t = np.array(e)

plt.scatter(a,e)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')

plt.plot(np.unique(a), np.poly1d(np.polyfit(a, e, 1))(np.unique(a)))
#plt.text(0.6, 0.5, 'R-squared = %0.2f' % r2_test)

# %%
# plotting validation fit
z=[]
a=[]
e=[]

for i in range(0,len(Y_val)):
  z.append(x_val[i][1])
  a.append(y_val[i][0])
  e.append(y_predval_inv[i][0])
r=np.array(z)
n=np.array(a)
t = np.array(e)

plt.scatter(a,e)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')

plt.plot(np.unique(a), np.poly1d(np.polyfit(a, e, 1))(np.unique(a)))
#plt.text(0.6, 0.5, 'R-squared = %0.2f' % r2_val)
